# %%
import numpy as np
import pandas as pd
import sklearn as sk

# %%
dataFrame = pd.read_csv(r'C:\Users\ahmra\Downloads\spam.csv', encoding='latin1')
dataFrame = dataFrame.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)
dataFrame = dataFrame.rename(columns={'v1': 'Label', 'v2': 'Content'})

# %%
X = dataFrame['Label']
Y = dataFrame['Content']
from sklearn.model_selection import train_test_split

train_X, train_Y, test_X, test_Y =  train_test_split(X, )
